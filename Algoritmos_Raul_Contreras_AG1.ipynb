# %% [markdown]
# <a href="https://colab.research.google.com/github/raulcontreraso-bit/00-VIU-Master-Universitario-IA-2026/blob/main/Algoritmos_Raul_Contreras_AG1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  AG1 - Actividad Guiada 1
# Asignatura: Algoritmos de Optimización
# Nombre y Apellidos: Raul Contreras O.
#
# Control de Versiones del Proyecto
# Url al repositorio de GitHub: https://github.com/raulcontreraso-bit/VIU-2026-Algoritmos-de-Optimizacion

# %%
print()
